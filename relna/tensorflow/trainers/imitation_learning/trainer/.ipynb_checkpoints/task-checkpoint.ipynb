# %%
import pickle as pkl
import os
from model import Model as ImitationTrainerModel

# %%
from GCSproxy import GCSproxy

# %%
local_expert_data_filename = "../../expert_data/RoboschoolHumanoid-v1.pkl"

# %%
gcs_expert_data_filename = "data/RoboschoolHumanoid-v1.pkl"

# %%
# convert to pandas -> numpy array

"""
expert_rollouts = pkl.load(open(expert_data_filename,"rb"))
import pandas as pd
X = pd.DataFrame(expert_rollouts['observations']).reset_index(drop=True).values
Y = pd.DataFrame(expert_rollouts['actions']).reset_index(drop=True).values
"""
# Out:
# '\nexpert_rollouts = pkl.load(open(expert_data_filename,"rb"))\nimport pandas as pd\nX = pd.DataFrame(expert_rollouts[\'observations\']).reset_index(drop=True).values\nY = pd.DataFrame(expert_rollouts[\'actions\']).reset_index(drop=True).values\n'

# %%
def load_data(expert_data_filename, mode):
    """
    returns numpy arrays X, Y
    X.shape = (, 44)
    Y.shape = (, 17)
    """
    if mode!="dev-local":
        proxy = GCSproxy(mode) 
        pkl_filename = proxy.gcs_load(expert_data_filename)
    else:
        pkl_filename = expert_data_filename

    expert_rollouts = pkl.load(open(pkl_filename,"rb"))  
    X = expert_rollouts['observations']
    Y = expert_rollouts['actions']
    assert len(X) == len(Y)
    return X, Y

# %%
def upload_model(source_model_dir, destination_model_dir):
    proxy = GCSproxy(mode="not running on mlengine") 
    proxy.gcs_write(source_model_dir, destination_model_dir)

# %%
X, Y = load_data(gcs_expert_data_filename)
# Out:
# [GCSproxy.gcs_load] interacting with Google Cloud Storage to retrieve data: data/RoboschoolHumanoid-v1.pkl

# %%
model = ImitationTrainerModel()

# %%
train_mse = model.train(X, Y)
# Out:
# WARNING:root:[model.py]:train - 0000 mse : 0.264
# WARNING:root:[model.py]:train - 1000 mse : 0.038
# WARNING:root:[model.py]:train - 2000 mse : 0.030
# WARNING:root:[model.py]:train - 3000 mse : 0.028
# WARNING:root:[model.py]:train - 4000 mse : 0.021
# WARNING:root:[model.py]:train - 5000 mse : 0.018
# WARNING:root:[model.py]:train - 6000 mse : 0.020
# WARNING:root:[model.py]:train - 7000 mse : 0.016
# WARNING:root:[model.py]:train - 8000 mse : 0.029
# WARNING:root:[model.py]:train - 9000 mse : 0.020
# WARNING:root:[model.py]:train - training complete
# WARNING:root:[model.py]:train - model saved to /tmp/model.ckpt

# %%
model.visualize_train_mse(train_mse)

# %%
y = model.predict(X)
# Out:
# WARNING:root:[model.py]:predict - loading model from /tmp/model.ckpt
# INFO:tensorflow:Restoring parameters from /tmp/model.ckpt
# INFO:tensorflow:Restoring parameters from /tmp/model.ckpt

# %%
model.evaluate_predictions(y, Y)
# Out:
# 0.33252398363576197

# %%
upload_model("/tmp/model.ckpt","output/imitation-learning/behavioural_cloning001.ckpt")
# Out:
# [GCSproxy.gcs_load] interacting with Google Cloud Storage to upload data: /tmp/model.ckpt
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-f4d72dc32018> in <module>
# ----> 1 upload_model("/tmp/model.ckpt","output/imitation-learning/behavioural_cloning001.ckpt")
#
# <ipython-input-7-8684c1205e24> in upload_model(source_model_dir, destination_model_dir)
#       1 def upload_model(source_model_dir, destination_model_dir):
#       2     proxy = GCSproxy(mode="not running on mlengine")
# ----> 3     proxy.gcs_write(source_model_dir, destination_model_dir)
#
# ~/Desktop/Coding/AI/relna/relna/tensorflow/trainers/imitation_learning/trainer/GCSproxy.py in gcs_write(self, source_file_name, destination_file_name)
#      42         print("[GCSproxy.gcs_load] interacting with Google Cloud Storage to upload data: {}".format(source_file_name))
#      43         blob = self.bucket.blob(destination_file_name)
# ---> 44         blob.upload_from_filename(source_file_name)
#
# ~/Desktop/Coding/AI/relna/venv/lib/python3.6/site-packages/google/cloud/storage/blob.py in upload_from_filename(self, filename, content_type, client, predefined_acl)
#    1203         content_type = self._get_content_type(content_type, filename=filename)
#    1204
# -> 1205         with open(filename, "rb") as file_obj:
#    1206             total_bytes = os.fstat(file_obj.fileno()).st_size
#    1207             self.upload_from_file(
#
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/model.ckpt'
